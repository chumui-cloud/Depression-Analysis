# %%
import pandas as pd
import numpy as np
df = pd.read_csv('MLData_final.csv')

# %%
df.head()
# Out:
#              Timestamp Which year are you in? How are you feeling right now?  \
# 0  11/23/2020 13:44:42               4th year                         Normal
# 1  11/23/2020 18:57:02               4th year                       Very bad
# 2  11/23/2020 20:38:17               4th year                            Bad
# 3   11/24/2020 0:34:05               4th year                         Normal
# 4  11/24/2020 10:36:29               4th year                         Normal
#
#    On a scale of 1-100, how would you express this feeling?  Gender  Age  \
# 0                                                 50         Female   22
# 1                                                 10         Female   22
# 2                                                 40         Female   22
# 3                                                 80         Female   22
# 4                                                 70         Female   22
#
#   Your location ? Relationship status  \
# 0            Home    It's complicated
# 1            Home    It's complicated
# 2            Home    It's complicated
# 3            Home    It's complicated
# 4            Home    It's complicated
#
#   Are you happy with your financial state?  \
# 0                                      Yes
# 1                                      Yes
# 2                                      Yes
# 3                                      Yes
# 4                                      Yes
#
#    How much have you succeeded to cope up with the environment of your educational institution?  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    ... Are you feeling pressure in your study or work right now?  \
# 0  ...                                                Yes
# 1  ...                                                Yes
# 2  ...                                                 No
# 3  ...                                                 No
# 4  ...                                                 No
#
#   Are you satisfied with your academic result?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#   Are you happy with your living place?  \
# 0                                   Yes
# 1                                   Yes
# 2                                   Yes
# 3                                   Yes
# 4                                   Yes
#
#   Who supports you when you are not succeeding in your academic life?  \
# 0                                            Friends
# 1                                             No one
# 2                                     Not applicable
# 3                                            Friends
# 4                                             No one
#
#   Have you used any social media within the last 6 hours?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do you have inferiority complex?  Are you satisfied with your meal today?  \
# 0                             Maybe                                     Yes
# 1                               Yes                                 Neutral
# 2                             Maybe                                 Neutral
# 3                             Maybe                                 Neutral
# 4                             Maybe                                 Neutral
#
#   Are you feeling sick/health issues today?  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                        No
# 4                                        No
#
#   Have you done any recreational activity (sports, gaming, hobby etc.) today?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How long did you sleep last night?(in hours)
# 0                                          8.0
# 1                                          8.0
# 2                                          8.0
# 3                                          8.0
# 4                                          8.0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 21 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Timestamp                                                                                     1700 non-null   object
#  1   Which year are you in?                                                                        1700 non-null   object
#  2   How are you feeling right now?                                                                1700 non-null   object
#  3   On a scale of 1-100, how would you express this feeling?                                      1700 non-null   int64
#  4   Gender                                                                                        1700 non-null   object
#  5   Age                                                                                           1700 non-null   int64
#  6   Your location ?                                                                               1700 non-null   object
#  7   Relationship status                                                                           1700 non-null   object
#  8   Are you happy with your financial state?                                                      1700 non-null   object
#  9   How much have you succeeded to cope up with the environment of your educational institution?  1700 non-null   int64
#  10  Understanding with your family members?                                                       1700 non-null   object
#  11  Are you feeling pressure in your study or work right now?                                     1700 non-null   object
#  12  Are you satisfied with your academic result?                                                  1700 non-null   object
#  13  Are you happy with your living place?                                                         1700 non-null   object
#  14  Who supports you when you are not succeeding in your academic life?                           1700 non-null   object
#  15  Have you used any social media within the last 6 hours?                                       1700 non-null   object
#  16  Do you have inferiority complex?                                                              1700 non-null   object
#  17  Are you satisfied with your meal today?                                                       1700 non-null   object
#  18  Are you feeling sick/health issues today?                                                     1700 non-null   object
#  19  Have you done any recreational activity (sports, gaming, hobby etc.) today?                   1700 non-null   object
#  20  How long did you sleep last night?(in hours)                                                  1700 non-null   float64
# dtypes: float64(1), int64(3), object(17)
# memory usage: 279.0+ KB

# %%
df.describe()
# Out:
#        On a scale of 1-100, how would you express this feeling?          Age  \
# count                                        1700.000000         1700.000000
# mean                                           57.169412           21.446471
# std                                            22.631256            1.610393
# min                                             1.000000           16.000000
# 25%                                            40.000000           20.000000
# 50%                                            60.000000           21.000000
# 75%                                            70.000000           22.000000
# max                                           100.000000           24.000000
#
#        How much have you succeeded to cope up with the environment of your educational institution?  \
# count                                        1700.000000
# mean                                            2.531765
# std                                             0.846446
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        How long did you sleep last night?(in hours)
# count                                   1700.000000
# mean                                       6.550000
# std                                        1.404556
# min                                        3.000000
# 25%                                        6.000000
# 50%                                        6.000000
# 75%                                        8.000000
# max                                       14.000000

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which year are you in?', 'How are you feeling right now?',
#        'On a scale of 1-100, how would you express this feeling?', 'Gender',
#        'Age', 'Your location ?', 'Relationship status',
#        'Are you happy with your financial state?',
#        'How much have you succeeded to cope up with the environment of your educational institution?',
#        'Understanding with your family members?',
#        'Are you feeling pressure in your study or work right now?',
#        'Are you satisfied with your academic result?',
#        'Are you happy with your living place?',
#        'Who supports you when you are not succeeding in your academic life?',
#        'Have you used any social media within the last 6 hours?',
#        'Do you have inferiority complex? ',
#        'Are you satisfied with your meal today?',
#        'Are you feeling sick/health issues today?',
#        'Have you done any recreational activity (sports, gaming, hobby etc.) today?',
#        'How long did you sleep last night?(in hours)'],
#       dtype='object')

# %%
df.drop('Timestamp', axis=1, inplace= True)

# %%
df.drop('Your location ?', axis=1, inplace= True)

# %%
df.describe(include=np.object)
# Out:
#        Which year are you in? How are you feeling right now?  Gender  \
# count                    1700                           1700    1700
# unique                      5                              5       1
# top                  4th year                           Good  Female
# freq                      638                            470    1700
#
#        Relationship status Are you happy with your financial state?  \
# count                 1700                                     1700
# unique                   4                                        2
# top                 Single                                      Yes
# freq                   644                                     1023
#
#        Understanding with your family members?  \
# count                                     1700
# unique                                       3
# top                                     Normal
# freq                                       949
#
#        Are you feeling pressure in your study or work right now?  \
# count                                                1700
# unique                                                  3
# top                                                    No
# freq                                                  880
#
#        Are you satisfied with your academic result?  \
# count                                          1700
# unique                                            3
# top                                             Yes
# freq                                            669
#
#        Are you happy with your living place?  \
# count                                   1700
# unique                                     3
# top                                      Yes
# freq                                     798
#
#        Who supports you when you are not succeeding in your academic life?  \
# count                                                1700
# unique                                                  5
# top                                               Friends
# freq                                                  784
#
#        Have you used any social media within the last 6 hours?  \
# count                                                1700
# unique                                                  3
# top                                                   Yes
# freq                                                 1181
#
#        Do you have inferiority complex?   \
# count                               1700
# unique                                 4
# top                                Maybe
# freq                                 630
#
#        Are you satisfied with your meal today?  \
# count                                     1700
# unique                                       3
# top                                    Neutral
# freq                                       655
#
#        Are you feeling sick/health issues today?  \
# count                                       1700
# unique                                         2
# top                                           No
# freq                                        1157
#
#        Have you done any recreational activity (sports, gaming, hobby etc.) today?
# count                                                1700
# unique                                                  2
# top                                                    No
# freq                                                 1018

# %%
label = LabelEncoder()
df['year'] = label.fit_transform(df['Which year are you in?'])
df['feelings'] = label.fit_transform(df['How are you feeling right now?'])
df['gender'] = label.fit_transform(df['Gender'])
df['rel_status'] = label.fit_transform(df['Relationship status'])
df['fin_state'] = label.fit_transform(df['Are you happy with your financial state?'])
df['un_fam'] = label.fit_transform(df['Understanding with your family members?'])
df['pressure'] = label.fit_transform(df['Are you feeling pressure in your study or work right now?'])
df['result_sat'] = label.fit_transform(df['Are you satisfied with your academic result?'])
df['living_place'] = label.fit_transform(df['Are you happy with your living place?'])
df['support'] = label.fit_transform(df['Who supports you when you are not succeeding in your academic life?'])
df['soc_media'] = label.fit_transform(df['Have you used any social media within the last 6 hours?'])
df['inferior_complex'] = label.fit_transform(df['Do you have inferiority complex? '])
df['meal'] = label.fit_transform(df['Are you satisfied with your meal today?'])
df['health_issue'] = label.fit_transform(df['Are you feeling sick/health issues today?'])
df['hobby'] = label.fit_transform(df['Have you done any recreational activity (sports, gaming, hobby etc.) today?'])

# %%
df.drop(['Which year are you in?', 'How are you feeling right now?', 'Gender', 'Relationship status',
       'Are you happy with your financial state?',
       'Understanding with your family members?',
       'Are you feeling pressure in your study or work right now?',
       'Are you satisfied with your academic result?',
       'Are you happy with your living place?',
       'Who supports you when you are not succeeding in your academic life?',
       'Have you used any social media within the last 6 hours?',
       'Do you have inferiority complex? ',
       'Are you satisfied with your meal today?',
       'Are you feeling sick/health issues today?',
       'Have you done any recreational activity (sports, gaming, hobby etc.) today?',
       ], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 19 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   On a scale of 1-100, how would you express this feeling?                                      1700 non-null   int64
#  1   Age                                                                                           1700 non-null   int64
#  2   How much have you succeeded to cope up with the environment of your educational institution?  1700 non-null   int64
#  3   How long did you sleep last night?(in hours)                                                  1700 non-null   float64
#  4   year                                                                                          1700 non-null   int32
#  5   feelings                                                                                      1700 non-null   int32
#  6   gender                                                                                        1700 non-null   int32
#  7   rel_status                                                                                    1700 non-null   int32
#  8   fin_state                                                                                     1700 non-null   int32
#  9   un_fam                                                                                        1700 non-null   int32
#  10  pressure                                                                                      1700 non-null   int32
#  11  result_sat                                                                                    1700 non-null   int32
#  12  living_place                                                                                  1700 non-null   int32
#  13  support                                                                                       1700 non-null   int32
#  14  soc_media                                                                                     1700 non-null   int32
#  15  inferior_complex                                                                              1700 non-null   int32
#  16  meal                                                                                          1700 non-null   int32
#  17  health_issue                                                                                  1700 non-null   int32
#  18  hobby                                                                                         1700 non-null   int32
# dtypes: float64(1), int32(15), int64(3)
# memory usage: 152.9 KB

# %%
df.rename(columns={'Age':'age','How long did you sleep last night?(in hours)':'sleep','How much have you succeeded to cope up with the environment of your educational institution?':'cope_with_ins'}, inplace=True)

# %%
df_copy= df

# %%
from sklearn.model_selection import train_test_split

# %%
df_copy.head()
# Out:
#    On a scale of 1-100, how would you express this feeling?  age  \
# 0                                                 50          22
# 1                                                 10          22
# 2                                                 40          22
# 3                                                 80          22
# 4                                                 70          22
#
#    cope_with_ins  sleep  year  feelings  gender  rel_status  fin_state  \
# 0              3    8.0     3         2       0           2          1
# 1              2    8.0     3         3       0           2          1
# 2              3    8.0     3         0       0           2          1
# 3              3    8.0     3         2       0           2          1
# 4              3    8.0     3         2       0           2          1
#
#    un_fam  pressure  result_sat  living_place  support  soc_media  \
# 0       2         2           0             2        1          2
# 1       2         2           0             2        2          2
# 2       2         0           0             2        3          2
# 3       2         0           0             2        1          2
# 4       0         0           0             2        2          2
#
#    inferior_complex  meal  health_issue  hobby
# 0                 0     2             0      0
# 1                 3     0             0      0
# 2                 0     0             0      0
# 3                 0     0             0      1
# 4                 0     0             0      0

# %%
df_copy.describe()
# Out:
#        On a scale of 1-100, how would you express this feeling?          age  \
# count                                        1700.000000         1700.000000
# mean                                           57.169412           21.446471
# std                                            22.631256            1.610393
# min                                             1.000000           16.000000
# 25%                                            40.000000           20.000000
# 50%                                            60.000000           21.000000
# 75%                                            70.000000           22.000000
# max                                           100.000000           24.000000
#
#        cope_with_ins        sleep         year     feelings  gender  \
# count    1700.000000  1700.000000  1700.000000  1700.000000  1700.0
# mean        2.531765     6.550000     1.898824     1.875294     0.0
# std         0.846446     1.404556     1.126124     1.377436     0.0
# min         1.000000     3.000000     0.000000     0.000000     0.0
# 25%         2.000000     6.000000     1.000000     1.000000     0.0
# 50%         3.000000     6.000000     2.000000     2.000000     0.0
# 75%         3.000000     8.000000     3.000000     3.000000     0.0
# max         5.000000    14.000000     4.000000     4.000000     0.0
#
#         rel_status    fin_state       un_fam     pressure   result_sat  \
# count  1700.000000  1700.000000  1700.000000  1700.000000  1700.000000
# mean      2.001176     0.601765     1.424118     0.807059     1.047059
# std       0.896661     0.489678     0.716086     0.897553     0.859197
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     0.000000     0.000000
# 50%       2.000000     1.000000     2.000000     0.000000     1.000000
# 75%       3.000000     1.000000     2.000000     2.000000     2.000000
# max       3.000000     1.000000     2.000000     2.000000     2.000000
#
#        living_place      support    soc_media  inferior_complex         meal  \
# count   1700.000000  1700.000000  1700.000000       1700.000000  1700.000000
# mean       1.044706     1.535882     1.450000          1.084706     0.961176
# std        0.944798     0.965811     0.858688          1.077296     0.854802
# min        0.000000     0.000000     0.000000          0.000000     0.000000
# 25%        0.000000     1.000000     1.000000          0.000000     0.000000
# 50%        1.000000     1.000000     2.000000          1.000000     1.000000
# 75%        2.000000     2.000000     2.000000          2.000000     2.000000
# max        2.000000     4.000000     2.000000          3.000000     2.000000
#
#        health_issue        hobby
# count   1700.000000  1700.000000
# mean       0.319412     0.401176
# std        0.466386     0.490281
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        1.000000     1.000000
# max        1.000000     1.000000

# %%
df_copy.drop('feelings_scaling', axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10844/204991571.py in <module>
# ----> 1 df_copy.drop('feelings_scaling', axis=1,inplace=True)
#
# c:\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# c:\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# c:\python\python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# c:\python\python37\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['feelings_scaling'] not found in axis"

# %%
target = df_copy['feelings']
df_copy.drop('feelings',axis=1, inplace=True)

# %%
df_copy.info()

# %%
X_train, X_test, Y_train,Y_test = train_test_split(df_copy,target, test_size=0.2, random_state=40)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
decision_tree.score(X_test, Y_test)
