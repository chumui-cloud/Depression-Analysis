# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('MLData_final.csv')
drop_cols = ['Timestamp','Your location ?','How are you feeling right now?','On a scale of 1-100, how would you express this feeling?']
df.drop(drop_cols, axis=1, inplace= True)

# %%
df.head()
# Out:
#   Which year are you in?  Gender  Age Relationship status  \
# 0               4th year  Female   22    It's complicated
# 1               4th year  Female   22    It's complicated
# 2               4th year  Female   22    It's complicated
# 3               4th year  Female   22    It's complicated
# 4               4th year  Female   22    It's complicated
#
#   Are you happy with your financial state?  \
# 0                                      Yes
# 1                                      Yes
# 2                                      Yes
# 3                                      Yes
# 4                                      Yes
#
#    How much have you succeeded to cope up with the environment of your educational institution?  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   Understanding with your family members?  \
# 0                                  Normal
# 1                                  Normal
# 2                                  Normal
# 3                                  Normal
# 4                                     Bad
#
#   Are you feeling pressure in your study or work right now?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Are you satisfied with your academic result?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#   Are you happy with your living place?  \
# 0                                   Yes
# 1                                   Yes
# 2                                   Yes
# 3                                   Yes
# 4                                   Yes
#
#   Who supports you when you are not succeeding in your academic life?  \
# 0                                            Friends
# 1                                             No one
# 2                                     Not applicable
# 3                                            Friends
# 4                                             No one
#
#   Have you used any social media within the last 6 hours?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Do you have inferiority complex?  Are you satisfied with your meal today?  \
# 0                             Maybe                                     Yes
# 1                               Yes                                 Neutral
# 2                             Maybe                                 Neutral
# 3                             Maybe                                 Neutral
# 4                             Maybe                                 Neutral
#
#   Are you feeling sick/health issues today?  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                        No
# 4                                        No
#
#   Have you done any recreational activity (sports, gaming, hobby etc.) today?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#    How long did you sleep last night?(in hours)
# 0                                           8.0
# 1                                           8.0
# 2                                           8.0
# 3                                           8.0
# 4                                           8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 17 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Which year are you in?                                                                        1700 non-null   object
#  1   Gender                                                                                        1700 non-null   object
#  2   Age                                                                                           1700 non-null   int64
#  3   Relationship status                                                                           1700 non-null   object
#  4   Are you happy with your financial state?                                                      1700 non-null   object
#  5   How much have you succeeded to cope up with the environment of your educational institution?  1700 non-null   int64
#  6   Understanding with your family members?                                                       1700 non-null   object
#  7   Are you feeling pressure in your study or work right now?                                     1700 non-null   object
#  8   Are you satisfied with your academic result?                                                  1700 non-null   object
#  9   Are you happy with your living place?                                                         1700 non-null   object
#  10  Who supports you when you are not succeeding in your academic life?                           1700 non-null   object
#  11  Have you used any social media within the last 6 hours?                                       1700 non-null   object
#  12  Do you have inferiority complex?                                                              1700 non-null   object
#  13  Are you satisfied with your meal today?                                                       1700 non-null   object
#  14  Are you feeling sick/health issues today?                                                     1700 non-null   object
#  15  Have you done any recreational activity (sports, gaming, hobby etc.) today?                   1700 non-null   object
#  16  How long did you sleep last night?(in hours)                                                  1700 non-null   float64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 225.9+ KB

# %%
label = LabelEncoder()
df['year'] = label.fit_transform(df['Which year are you in?'])
df['gender'] = label.fit_transform(df['Gender'])
df['rel_status'] = label.fit_transform(df['Relationship status'])
df['fin_state'] = label.fit_transform(df['Are you happy with your financial state?'])
df['un_fam'] = label.fit_transform(df['Understanding with your family members?'])
df['pressure'] = label.fit_transform(df['Are you feeling pressure in your study or work right now?'])
df['result_sat'] = label.fit_transform(df['Are you satisfied with your academic result?'])
df['living_place'] = label.fit_transform(df['Are you happy with your living place?'])
df['support'] = label.fit_transform(df['Who supports you when you are not succeeding in your academic life?'])
df['soc_media'] = label.fit_transform(df['Have you used any social media within the last 6 hours?'])
df['inferior_complex'] = label.fit_transform(df['Do you have inferiority complex? '])
df['meal'] = label.fit_transform(df['Are you satisfied with your meal today?'])
df['health_issue'] = label.fit_transform(df['Are you feeling sick/health issues today?'])
df['hobby'] = label.fit_transform(df['Have you done any recreational activity (sports, gaming, hobby etc.) today?'])

# %%
df.head()
# Out:
#   Which year are you in?  Gender  Age Relationship status  \
# 0               4th year  Female   22    It's complicated
# 1               4th year  Female   22    It's complicated
# 2               4th year  Female   22    It's complicated
# 3               4th year  Female   22    It's complicated
# 4               4th year  Female   22    It's complicated
#
#   Are you happy with your financial state?  \
# 0                                      Yes
# 1                                      Yes
# 2                                      Yes
# 3                                      Yes
# 4                                      Yes
#
#    How much have you succeeded to cope up with the environment of your educational institution?  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#   Understanding with your family members?  \
# 0                                  Normal
# 1                                  Normal
# 2                                  Normal
# 3                                  Normal
# 4                                     Bad
#
#   Are you feeling pressure in your study or work right now?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Are you satisfied with your academic result?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
#
#   Are you happy with your living place?  ... un_fam pressure result_sat  \
# 0                                   Yes  ...      2        2          0
# 1                                   Yes  ...      2        2          0
# 2                                   Yes  ...      2        0          0
# 3                                   Yes  ...      2        0          0
# 4                                   Yes  ...      0        0          0
#
#   living_place support soc_media  inferior_complex  meal  health_issue  hobby
# 0            2       1         2                 0     2             0      0
# 1            2       2         2                 3     0             0      0
# 2            2       3         2                 0     0             0      0
# 3            2       1         2                 0     0             0      1
# 4            2       2         2                 0     0             0      0
#
# [5 rows x 31 columns]

# %%
df.drop(['Which year are you in?','Gender', 'Relationship status',
       'Are you happy with your financial state?',
       'Understanding with your family members?',
       'Are you feeling pressure in your study or work right now?',
       'Are you satisfied with your academic result?',
       'Are you happy with your living place?',
       'Who supports you when you are not succeeding in your academic life?',
       'Have you used any social media within the last 6 hours?',
       'Do you have inferiority complex? ',
       'Are you satisfied with your meal today?',
       'Are you feeling sick/health issues today?',
       'Have you done any recreational activity (sports, gaming, hobby etc.) today?',
       ], axis=1, inplace=True)

# %%
df.rename(columns={'Age':'age','How long did you sleep last night?(in hours)':'sleep','How much have you succeeded to cope up with the environment of your educational institution?':'cope_with_ins'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1700 non-null   int64
#  1   cope_with_ins     1700 non-null   int64
#  2   sleep             1700 non-null   float64
#  3   year              1700 non-null   int32
#  4   gender            1700 non-null   int32
#  5   rel_status        1700 non-null   int32
#  6   fin_state         1700 non-null   int32
#  7   un_fam            1700 non-null   int32
#  8   pressure          1700 non-null   int32
#  9   result_sat        1700 non-null   int32
#  10  living_place      1700 non-null   int32
#  11  support           1700 non-null   int32
#  12  soc_media         1700 non-null   int32
#  13  inferior_complex  1700 non-null   int32
#  14  meal              1700 non-null   int32
#  15  health_issue      1700 non-null   int32
#  16  hobby             1700 non-null   int32
# dtypes: float64(1), int32(14), int64(2)
# memory usage: 132.9 KB

# %%
df_copy= df
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(df_copy)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
print(kmeans.cluster_centers_)
print(kmeans.labels_)
# Out:
# [[21.40065147  2.42345277  5.40065147  1.83061889  0.          1.70684039
#    0.59283388  1.38110749  1.57654723  1.12052117  1.11400651  2.21172638
#    1.71009772  0.09120521  0.58306189  0.31596091  0.29967427]
#  [23.76619718  2.18309859  7.87605634  2.96901408  0.          2.83943662
#    0.97183099  1.4084507   0.71830986  1.52394366  1.07887324  1.23380282
#    1.69859155  1.26760563  0.67605634  0.67042254  0.21690141]
#  [21.62857143  3.1012987   7.1012987   2.69350649  0.          1.74285714
#    0.51168831  1.63896104  0.32727273  0.4987013   1.92467532  0.85194805
#    1.1012987   0.56883117  1.43376623  0.14025974  0.41298701]
#  [19.66666667  3.19191919  5.32323232  1.01010101  0.          1.76767677
#    0.33670034  1.45791246  0.43097643  1.52861953  0.44781145  0.98316498
#    1.1010101   1.63299663  0.85521886  0.19191919  0.4983165 ]
#  [20.46067416  1.80617978  6.64606742  0.77247191  0.          1.89325843
#    0.55898876  1.21629213  1.06460674  0.6994382   0.49719101  2.45505618
#    1.64606742  1.85955056  1.1488764   0.27247191  0.57865169]]
# [2 1 2 ... 1 0 4]

# %%
y_kmeans = kmeans.predict(df_copy)
metrics.adjusted_rand_score(target, y_kmeans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6612/3449994044.py in <module>
#       1 y_kmeans = kmeans.predict(df_copy)
# ----> 2 metrics.adjusted_rand_score(target, y_kmeans)
#
# NameError: name 'target' is not defined
